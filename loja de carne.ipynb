# %% [markdown]
# <a href="https://colab.research.google.com/github/kyori77/python/blob/main/loja%20de%20carne.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('                      Até 5 Kg           Acima de 5 Kg')
print('1 - File Duplo      R$ 4,90 por Kg          R$ 5,80 por Kg')
print('2 - Alcatra         R$ 5,90 por Kg          R$ 6,80 por Kg')
print('3 - Picanha         R$ 6,90 por Kg          R$ 7,80 por Kg')

produto = int(input('Informe o tipo da carne :'))
kilos = float(input('Informe o peso : '))
qtd= int(input('Informe a quantidade : '))
# Out:
#                       Até 5 Kg           Acima de 5 Kg
# 1 - File Duplo      R$ 4,90 por Kg          R$ 5,80 por Kg
# 2 - Alcatra         R$ 5,90 por Kg          R$ 6,80 por Kg
# 3 - Picanha         R$ 6,90 por Kg          R$ 7,80 por Kg
# Informe o tipo da carne :1
